# %% [markdown]
# # parse_logfile
#
# This dict is the result of serialising (then cleaning) a logfile which is dumped when the assertion on line ~700 fails:
# ```
# assert target.name not in self.converter._function_definitions, target.name
# ```
#
# Look at this dict, parse how the three relevant objects are filled (really two are objects, one is a call history)

# %%
import json


from typed_python import SerializationContext

# %%
SERIALIZED_INPUT = '/home/wgrant/Dev/typed_python/demos/python_s_slow_u_slice_u_3/logfile_20221122.bytes'
# SERIALIZED_INPUT = '/home/wgrant/Dev/typed_python/logfile.bytes'

# %%
# !ls -l {SERIALIZED_INPUT}
# Out:
# -rw-r--r-- 1 wgrant wgrant 64986 Nov 22 18:46 /home/wgrant/Dev/typed_python/demos/python_s_slow_u_slice_u_3/logfile_20221122.bytes

# %%
with open(SERIALIZED_INPUT, 'rb') as flines:
    input_data = SerializationContext().deserialize(flines.read())

# %%
# PATH_TO_INPUT = '/home/wgrant/Dev/typed_python/demos/failure_dict.json'
# with open(PATH_TO_INPUT) as flines:
#     input_data = json.load(flines)

# %%
for key, value in input_data.items():
    print(key, len(value))
# Out:
# history 4
# end_state 3
# compiler_cache 4
# bug_test 0

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 2000)

# %% [markdown]
# ## History

# %%
def parse_dict_to_dataframe(input_dict: dict) -> pd.DataFrame:
    input_data_squared = []
    for key, value in input_dict.items():
        for x in value:
            try:
                timestamp, thread, data = x
            except TypeError:
                timestamp, thread, data = x, None
            input_data_squared.append((pd.to_datetime(timestamp, unit='s'), thread, key, data))
    input_df = pd.DataFrame(input_data_squared, columns=['timestamp', 'thread', 'key', 'data']).sort_values(by='timestamp').reset_index(drop=True)
    
    # extract the callTarget data
    callTarget_data = pd.json_normalize(input_df.query('key=="namedCallTargetToLLVM"').data).set_index(input_df.query('key=="namedCallTargetToLLVM"').index)
    callTarget_data.columns = ['name', 'namedCallTargetToLLVM.external']
    parsed_df = pd.merge(input_df, callTarget_data, how='left', left_index=True, right_index=True)
    parsed_df.loc[parsed_df.key=="namedCallTargetToLLVM", 'data'] = None
    # set the name field as data for function_definitions
    parsed_df.loc[parsed_df.key=="function_definitions", 'name'] = parsed_df.loc[parsed_df.key=="function_definitions", :].data  
    parsed_df.loc[parsed_df.key=="external_function_references", 'name'] = parsed_df.loc[parsed_df.key=="external_function_references", :].data  
    # blow up the externallyDefinedFunctionTypes
    parsed_df = parsed_df.explode('data')
    parsed_df.loc[parsed_df.key=="externallyDefinedFunctionTypes", 'name'] = parsed_df.loc[parsed_df.key=="externallyDefinedFunctionTypes", :].data
    # grab entryPoint names
    parsed_df.loc[parsed_df.key=="entryPoint", 'name'] = input_df.loc[input_df.key=='entryPoint', 'data'].apply(lambda x: x['name'])
    
    parsed_df = parsed_df.drop(columns=['data']).reset_index(drop=True)
    return parsed_df, input_df

# %%
df, input_df = parse_dict_to_dataframe(input_data['history'])

# %%
import numpy as np

# %%
def bold(row):
    if not pd.isnull(row['name']) and 'decref_str' in row['name']:
        return ['background-color: #1b9e77'] * len(row)
    elif row['name'] == 'CLEAR':
        return ['background-color: #d95f02'] * len(row)
        
    else:
        return [None] * len(row)

# %%
# df.style.apply(bold, axis=1)

# %%
# df[df.key == 'external_function_references']

# %%
# df[(df.name.notnull() & df.name.str.contains('decref_str')) | (df.key == 'external_function_references')]

# %%
repeated_names = df[df.key.isin(['function_definitions', 'externallyDefinedFunctionTypes'])].name.value_counts()

# %%
repeated_names = repeated_names[repeated_names > 1].index

# %%
repeated_names
# Out:
# Index([], dtype='object')

# %%
# df[df.name.isin(repeated_names)]

# %% [markdown]
# ## End State

# %%
def parse_dict_to_end_state_dataframe(input_dict): 
    protodf = []
    for key, value in input_dict['end_state'].items():
        if key == 'namedCallTargetToLLVM':
            continue
        timestamp, thread, function_names = value
        for name in function_names:
            protodf.append((pd.to_datetime(timestamp, unit='s'), thread, key, name))
    end_state = pd.DataFrame(protodf, columns=['timestamp', 'thread', 'key', 'name']).sort_values(by=['key', 'name'])
    return end_state

# %%
# parse_dict_to_end_state_dataframe(input_data).style.apply(bold,axis=1)

# %%
input_data['end_state']['namedCallTargetToLLVM']
# Out:
# [1669160808.2517753,
#  2005,
#  {'name': 'runtime.type_convert(NoneType -> OneOf(None, int), conversionLevel=4).35c4c96d5009d1f818454d90c070b56da027a651',
#   'external': False}]

# %% [markdown]
# ## Compiler Stuff

# %%
for key, value in input_data.items():
    print(key, len(value))
# Out:
# history 4
# end_state 3
# compiler_cache 4
# bug_test 0

# %%
def parse_dict_to_compiler_cache_dataframe(input_dict): 
    protodf = []
    for key, value in input_dict['compiler_cache'].items():
        for timestamp, thread, function_name in value:
            protodf.append((pd.to_datetime(timestamp, unit='s'), thread, key, function_name))
    compiler_cache = pd.DataFrame(protodf, columns=['timestamp', 'thread', 'key', 'name']).sort_values(by='timestamp')
    return compiler_cache

# %%
compiler_df =parse_dict_to_compiler_cache_dataframe(input_data)

# %%
compiler_df[compiler_df.name.str.contains('decref_str')]
# Out:
#                         timestamp  thread           key  \
# 112 2022-11-22 23:46:47.666805248    2005  load_results
# 332 2022-11-22 23:46:47.836373504    2005  load_results
# 627 2022-11-22 23:46:47.923132416    2005  load_results
#
#                                                   name
# 112  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 332  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 627  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...

# %%
# compiler_df.style.apply(bold,axis=1)

# %% [markdown]
# ## Bug Test -

# %%
def parse_dict_to_bug_test_dataframe(input_dict): 
    protodf = []
    for timestamp, thread, value in input_dict['bug_test']:
        for key, vals in value.items():
            for function_name in vals:
                protodf.append((pd.to_datetime(timestamp, unit='s'), thread, key, function_name))
    bug_test = pd.DataFrame(protodf, columns=['timestamp', 'thread', 'key', 'name']).sort_values(by=['timestamp', 'key']).reset_index(drop=True)
    return bug_test

# %%
# bug_test_df = parse_dict_to_bug_test_dataframe(input_data)

# %%
# bug_test_df[bug_test_df.name.str.contains('decref_str')]

# %%
# bug_test_df.style.apply(bold, axis=1)

# %%
# rows = []
# for index, row in bug_test_df.query('key=="markExternal"').iterrows():
#     name = row['name']
#     preceding_rows = bug_test_df.iloc[:index].query('name==@name and key=="definedNames"')
#     if len(preceding_rows):   
#         # rows.append(pd.concat([preceding_rows, row]))
#         rows.append(preceding_rows.append(row))

# %%
# defined_then_loaded = pd.concat(rows)

# %%
# defined_then_loaded

# %%
# defined_then_loaded_names = defined_then_loaded['name'].unique()

# %%
# print("\n".join(sorted(defined_then_loaded['name'].unique())))

# %%
# print("\n".join(sorted(repeated_names)))

# %%
# defined_then_loaded

# %%
# merged[merged.name.isin(defined_then_loaded['name'].unique())].style

# %%
repeated_names
# Out:
# Index([], dtype='object')

# %%
# bug_test_df

# %% [markdown]
# ## Combo

# %%
history_df = df.drop(columns='namedCallTargetToLLVM.external')

# %%
history_df.shape
# Out:
# (579, 4)

# %%
compiler_df.shape
# Out:
# (1030, 4)

# %%
merged = pd.concat([history_df, compiler_df]).sort_values(by=['timestamp', 'key', 'name'])

# %%
# merged

# %%
merged[merged.name.str.contains('decref_str')]
# Out:
#                         timestamp  thread                           key  \
# 112 2022-11-22 23:46:47.666805248    2005                  load_results
# 332 2022-11-22 23:46:47.836373504    2005                  load_results
# 627 2022-11-22 23:46:47.923132416    2005                  load_results
# 508 2022-11-22 23:46:48.196358400    2005         namedCallTargetToLLVM
# 509 2022-11-22 23:46:48.196428032    2005  external_function_references
#
#                                                   name
# 112  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 332  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 627  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 508  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 509  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...

# %%
# merged[merged.key.isin(['namedCallTargetToLLVM', 'external_function_references'])]

# %%
# df[df['namedCallTargetToLLVM.external'] == False]

# %%
# merged

# %%
# check end_state to debug how on earth NCT2LLVM got called thrice

# %%
# df.iloc[-100:]

# %%
# end_state_df = parse_dict_to_end_state_dataframe(input_data)

# %%
# end_state_df[end_state_df.name.str.contains('checkSetSizeAndThrow')]

# %%
# end_state_df.query("key=='function_definitions'")

# %% [markdown]
# So what happened:
# -  defineLinkName called with RDS - added to `_allDefinedNames_` and then loadFromCompilerCache hit. symbol found in the cache but either callTargetsAndTypes was None, or newNativeFunctionTypes is empty.
# - then RDS added to function_definitions.
# - call NCT2LLVM a bunch of times.
# - then load RDS again, as a result of loadFromCompilerCaching a different function **which function**. RDS gets in EDFTs, ADS, ACS
# - then three more NCT2LLVM hits, and only the third breaks?

# %%
# merged.loc[1048]

# %%
# merged.index.get_loc(1048)

# %%
# merged[600:792]

# %%
# merged[791:1000]

# %% [markdown]
# For each function, get the first occurences of namedCallTargetToLLVM, and all external_function_references

# %%
# repeated_names

# %%
# external_function_refs = merged.query("key=='external_function_references'")
# namedCallTargetToLLVM_firstcall = merged.query("key=='namedCallTargetToLLVM'").groupby('name').first().reset_index()
# pd.concat([namedCallTargetToLLVM_firstcall, external_function_refs]).sort_values(by='timestamp')[['timestamp', 'thread', 'key', 'name']].style

# %%
# defined_then_loaded

# %%
# history_df.query("key=='function_definitions'")

# %%
# merged[merged.name.str.contains('decref_str')]

# %%
# merged.query("key=='external_function_references'")

# %%
# repeated_names

# %%
# defined_then_loaded_names

# %%
# external_referenced_names = merged.query("key=='external_function_references'").name.unique()

# %%
# set(defined_then_loaded_names) - set(repeated_names )

# %%
merged[merged.name.str.contains('decref_str')]
# Out:
#                         timestamp  thread                           key  \
# 112 2022-11-22 23:46:47.666805248    2005                  load_results
# 332 2022-11-22 23:46:47.836373504    2005                  load_results
# 627 2022-11-22 23:46:47.923132416    2005                  load_results
# 508 2022-11-22 23:46:48.196358400    2005         namedCallTargetToLLVM
# 509 2022-11-22 23:46:48.196428032    2005  external_function_references
#
#                                                   name
# 112  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 332  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 627  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 508  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...
# 509  runtime.decref_str.6ff674b5be11a1473ce627fb8bd...

# %%
merged.reset_index(drop=True).style.apply(bold,axis=1)
# Out:
# <style type="text/css">
# #T_55754_row0_col0, #T_55754_row0_col1, #T_55754_row0_col2, #T_55754_row0_col3 {
#   background-color: #d95f02;
# }
# #T_55754_row448_col0, #T_55754_row448_col1, #T_55754_row448_col2, #T_55754_row448_col3, #T_55754_row726_col0, #T_55754_row726_col1, #T_55754_row726_col2, #T_55754_row726_col3, #T_55754_row1029_col0, #T_55754_row1029_col1, #T_55754_row1029_col2, #T_55754_row1029_col3, #T_55754_row1538_col0, #T_55754_row1538_col1, #T_55754_row1538_col2, #T_55754_row1538_col3, #T_55754_row1539_col0, #T_55754_row1539_col1, #T_55754_row1539_col2, #T_55754_row1539_col3 {
#   background-color: #1b9e77;
# }
# </style>
# <table id="T_55754">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55754_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_55754_level0_col1" class="col_heading level0 col1" >thread</th>
#       <th id="T_55754_level0_col2" class="col_heading level0 col2" >key</th>
#       <th id="T_55754_level0_col3" class="col_heading level0 col3" >name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55754_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55754_row0_col0" class="data row0 col0" >2022-11-22 23:46:44.558111744</td>
#       <td id="T_55754_row0_col1" class="data row0 col1" >2001</td>
#       <td id="T_55754_row0_col2" class="data row0 col2" >function_definitions</td>
#       <td id="T_55754_row0_col3" class="data row0 col3" >CLEAR</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55754_row1_col0" class="data row1 col0" >2022-11-22 23:46:44.558223872</td>
#       <td id="T_55754_row1_col1" class="data row1 col1" >2001</td>
#       <td id="T_55754_row1_col2" class="data row1 col2" >entryPoint</td>
#       <td id="T_55754_row1_col3" class="data row1 col3" >getNonblocking</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55754_row2_col0" class="data row2 col0" >2022-11-22 23:46:44.558497280</td>
#       <td id="T_55754_row2_col1" class="data row2 col1" >2001</td>
#       <td id="T_55754_row2_col2" class="data row2 col2" >entryPoint</td>
#       <td id="T_55754_row2_col3" class="data row2 col3" >get</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55754_row3_col0" class="data row3 col0" >2022-11-22 23:46:44.558671104</td>
#       <td id="T_55754_row3_col1" class="data row3 col1" >2001</td>
#       <td id="T_55754_row3_col2" class="data row3 col2" >entryPoint</td>
#       <td id="T_55754_row3_col3" class="data row3 col3" >getMany</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55754_row4_col0" class="data row4 col0" >2022-11-22 23:46:44.558844672</td>
#       <td id="T_55754_row4_col1" class="data row4 col1" >2001</td>
#       <td id="T_55754_row4_col2" class="data row4 col2" >entryPoint</td>
#       <td id="T_55754_row4_col3" class="data row4 col3" >put</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55754_row5_col0" class="data row5 col0" >2022-11-22 23:46:44.558963200</td>
#       <td id="T_55754_row5_col1" class="data row5 col1" >2001</td>
#       <td id="T_55754_row5_col2" class="data row5 col2" >entryPoint</td>
#       <td id="T_55754_row5_col3" class="data row5 col3" >putMany</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_55754_row6_col0" class="data row6 col0" >2022-11-22 23:46:44.559899648</td>
#       <td id="T_55754_row6_col1" class="data row6 col1" >2001</td>
#       <td id="T_55754_row6_col2" class="data row6 col2" >entryPoint</td>
#       <td id="T_55754_row6_col3" class="data row6 col3" >peek</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_55754_row7_col0" class="data row7 col0" >2022-11-22 23:46:44.560040704</td>
#       <td id="T_55754_row7_col1" class="data row7 col1" >2001</td>
#       <td id="T_55754_row7_col2" class="data row7 col2" >entryPoint</td>
#       <td id="T_55754_row7_col3" class="data row7 col3" >__len__</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_55754_row8_col0" class="data row8 col0" >2022-11-22 23:46:44.560932096</td>
#       <td id="T_55754_row8_col1" class="data row8 col1" >2001</td>
#       <td id="T_55754_row8_col2" class="data row8 col2" >entryPoint</td>
#       <td id="T_55754_row8_col3" class="data row8 col3" >workExecutor</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_55754_row9_col0" class="data row9 col0" >2022-11-22 23:46:44.561108736</td>
#       <td id="T_55754_row9_col1" class="data row9 col1" >2001</td>
#       <td id="T_55754_row9_col2" class="data row9 col2" >entryPoint</td>
#       <td id="T_55754_row9_col3" class="data row9 col3" >pmap</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_55754_row10_col0" class="data row10 col0" >2022-11-22 23:46:45.009092096</td>
#       <td id="T_55754_row10_col1" class="data row10 col1" >2005</td>
#       <td id="T_55754_row10_col2" class="data row10 col2" >entryPoint</td>
#       <td id="T_55754_row10_col3" class="data row10 col3" >minOf</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_55754_row11_col0" class="data row11 col0" >2022-11-22 23:46:45.009393920</td>
#       <td id="T_55754_row11_col1" class="data row11 col1" >2005</td>
#       <td id="T_55754_row11_col2" class="data row11 col2" >entryPoint</td>
#       <td id="T_55754_row11_col3" class="data row11 col3" >maxOf</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_55754_row12_col0" class="data row12 col0" >2022-11-22 23:46:45.769393152</td>
#       <td id="T_55754_row12_col1" class="data row12 col1" >2005</td>
#       <td id="T_55754_row12_col2" class="data row12 col2" >entryPoint</td>
#       <td id="T_55754_row12_col3" class="data row12 col3" >_updateFromObservations</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_55754_row13_col0" class="data row13 col0" >2022-11-22 23:46:46.259834112</td>
#       <td id="T_55754_row13_col1" class="data row13 col1" >2005</td>
#       <td id="T_55754_row13_col2" class="data row13 col2" >allDefinedNames</td>
#       <td id="T_55754_row13_col3" class="data row13 col3" >tp._updateFromObservations.529ee59fe9ee0d764899a180d7186aa92d094dcc</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_55754_row14_col0" class="data row14 col0" >2022-11-22 23:46:46.259872256</td>
#       <td id="T_55754_row14_col1" class="data row14 col1" >2005</td>
#       <td id="T_55754_row14_col2" class="data row14 col2" >load_call</td>
#       <td id="T_55754_row14_col3" class="data row14 col3" >tp._updateFromObservations.529ee59fe9ee0d764899a180d7186aa92d094dcc</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_55754_row15_col0" class="data row15 col0" >2022-11-22 23:46:46.267470080</td>
#       <td id="T_55754_row15_col1" class="data row15 col1" >2005</td>
#       <td id="T_55754_row15_col2" class="data row15 col2" >allDefinedNames</td>
#       <td id="T_55754_row15_col3" class="data row15 col3" >runtime.copy_initialize_Value.f8070df09eb163497c2c5e4a3895b86b28cebc5e</td>
#     </tr>
#     <tr>
#       <th id="T_55754_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_55754_row16_col0" class="data row16 col0" >2022-11-22 23:46:46.299068672</td>
#       <td id="T_55754_row16_col1" class="data row16 col1" >2005</td>
#       <td id="T_55754_row16_col2" class="data row16 col2" >entryPoint</td>
